# %%
import json
import itertools

with open('../geojson-data/spb.geojson') as f:
    city = json.load(f)

with_other_tags = city['features']

with_amenity = [f for f in with_other_tags if 'amenity' in f['properties'].keys()]

relevant_amenities = ['fast_food', 'cafe', 'restaurant', 'nightclub', 'stripclub', 
                 'pub', 'bar', 'courthouse', 'register_office', 'townhall', 
                 'public_building', 'police', 'place_of_worship', 'fountain', 
                 'library', 'theatre', 'clinic', 'hospital', 'bank', 'university',
                 'school', 'cinema']

entries = {a: [] for a in relevant_amenities}
for feature in with_amenity:
    amenity = feature['properties']['amenity']
    if amenity in relevant_amenities:
        entrie = [feature['geometry']['coordinates']]
        if 'name' in feature['properties'].keys():
            entrie.append(feature['properties']['name'])
        entries[amenity].append(entrie)
        
def retreive(tag, value=None): 
    res = [f for f in with_other_tags if tag in f['properties'].keys()]
    if not value is None:
        res = [ f for f in res if f['properties'][tag] == value]
    return res


retrieved = {
    'public_transport': retreive('public_transport'),
    'tram_stop': retreive('railway', 'tram_stop'),
    'subway_station': retreive('station', 'subway'),
    'shop': retreive('shop'),
    'sport_center': retreive('leisure', 'sports_centre'),
    'playground': retreive('leisure', 'playground'),
    'railway': retreive('railway'),
    'office': retreive('office'),
    'monument': retreive('historic', 'monument'),
    'memorial': retreive('historic', 'memorial'),
    'fitness_centre': retreive('leisure', 'fitness_centre'),
    'motel': retreive('tourism', 'motel'),
    'hotel': retreive('tourism', 'hotel'),
    'hostel': retreive('tourism', 'hostel'),
    'artwork': retreive('tourism', 'artwork')
}

for key in retrieved.keys():
    entries[key] = []

    
for key, features in zip(retrieved.keys(), retrieved.values()):
    for feature in features:
        entrie = [feature['geometry']['coordinates']]
        if 'name' in feature['properties'].keys():
            entrie.append(feature['properties']['name'])
        entries[key].append(entrie)
        
with open('../extracted-entries/spb.json', 'w') as fp:
    json.dump(entries, fp)

# %%
with_amenity[:100]
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4101807, 59.9453356]},
#   'properties': {'ref': '305',
#    'amenity': 'post_box',
#    'operator': 'Почта России',
#    'design:year': '2010',
#    'drive_through': 'no',
#    'post_box:type': 'wall',
#    'post_box:design': 'ЯПНМ-II-С',
#    'collection_times': 'Mo-Fr 04:15,12:25; Sa 09:00; Su 12:25'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3085901, 59.9673052]},
#   'properties': {'name': 'Jam Hall', 'amenity': 'cinema'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3872517, 59.9749369]},
#   'properties': {'amenity': 'atm',
#    'website': 'http://www.vtb24.ru/',
#    'operator': 'ВТБ24'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2332697, 59.9693246]},
#   'properties': {'name': 'Русская рыбалка', 'amenity': 'restaurant'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.254421, 59.9710726]},
#   'properties': {'name': 'JetSet', 'amenity': 'bicycle_rental'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3066182, 59.9587217]},
#   'properties': {'name': 'Харчевня XIV век',
#    'source': 'survey',
#    'amenity': 'restaurant',
#    'cuisine': 'international',
#    'website': 'https://vk.com/club79814308',
#    'old_name': 'Дубравка;Престиж',
#    'opening_hours': 'Mo-Fr 11:00-00:00; Sa-Su 12:00-00:00',
#    'internet_access': 'wlan'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3023557, 59.9595399]},
#   'properties': {'name': 'Мираж Синема',
#    'phone': '+7(812)677-15-92',
#    'amenity': 'cinema',
#    'website': 'http://www.mirage.ru',
#    'opening_hours': '24/7'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3104206, 59.9618364]},
#   'properties': {'name': 'Кофейня "Аддис"',
#    'phone': '+7 911 834-31-25',
#    'amenity': 'restaurant',
#    'cuisine': 'breakfast;coffee_shop;ice_cream',
#    'name:en': 'Addis',
#    'website': 'http://vk.com/coffeeaddis',
#    'opening_hours': 'Mo-Su 11:00-22:00',
#    'internet_access': 'wlan'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3068701, 59.9627191]},
#   'properties': {'name': 'Мама Рома',
#    'phone': '+7 812 2305597',
#    'amenity': 'restaurant',
#    'cuisine': 'italian',
#    'name:en': 'Mama Roma',
#    'website': 'http://www.mamaroma.ru/',
#    'opening_hours': 'Mo-Su 11:00-01:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.31199, 59.9592619]},
#   'properties': {'name': 'Слойка',
#    'amenity': 'cafe',
#    'opening_hours': '09:00-19:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3177769, 59.9596438]},
#   'properties': {'atm': 'yes',
#    'bic': 'RZBMRUMM',
#    'name': 'Райффайзен',
#    'brand': 'Райффайзен',
#    'amenity': 'bank',
#    'name:en': 'Raiffeisen',
#    'name:ru': 'Райффайзен',
#    'int_name': 'Raiffeisen',
#    'contact:vk': 'https://vk.com/raiffeisenbankrus',
#    'description': 'Отделение А «Австрийская площадь»',
#    'contact:email': 'avstriyskaya.spb@raiffeisen.ru',
#    'contact:phone': '+7 812 3344343',
#    'opening_hours': 'Mo-Fr 11:00-20:00; Sa 11:00-17:00',
#    'brand:wikidata': 'Q4389244',
#    'brand:wikipedia': 'ru:Райффайзенбанк',
#    'contact:twitter': 'https://twitter.com/Raiffeisen_Ru',
#    'contact:website': 'https://www.raiffeisen.ru',
#    'contact:facebook': 'https://www.facebook.com/raiffeisenbankrus',
#    'contact:telegram': 'https://telegram.me/RaiffeisenbankBot',
#    'contact:instagram': 'https://www.instagram.com/raiffeisenbank_rus'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.321172, 59.9564346]},
#   'properties': {'name': 'Балтийский банк', 'amenity': 'atm'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3475786, 59.9325242]},
#   'properties': {'name': 'Две палочки',
#    'amenity': 'restaurant',
#    'cuisine': 'japanese;sushi',
#    'website': 'http://dvepalochki.ru/restaurants/nevskiy-pr-47/',
#    'alt_name': '2 палочки',
#    'contact:vk': 'https://vk.com/dvepalochki',
#    'opening_hours': '24/7',
#    'internet_access': 'wlan',
#    'payment:debit_cards': 'yes',
#    'payment:credit_cards': 'yes'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.306516, 59.9634627]},
#   'properties': {'name': 'Приют гурмана', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.301681, 59.9631631]},
#   'properties': {'name': 'Снежинка', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.305668, 59.9594062]},
#   'properties': {'name': 'La Izvor', 'amenity': 'restaurant'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3073337, 59.9609192]},
#   'properties': {'atm': 'yes',
#    'name': 'СДМ-БАНК',
#    'amenity': 'bank',
#    'addr:street': 'улица Ленина',
#    'addr:housenumber': '14'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2860197, 59.9666869]},
#   'properties': {'name': 'La Fabrik',
#    'amenity': 'restaurant',
#    'opening_hours': 'Mo-Fr 10:00-23:30; Sa-Su 12:00-23:30'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3132049, 59.9153967]},
#   'properties': {'name': 'SПБ',
#    'amenity': 'bar',
#    'website': 'http://www.barspb.ru/',
#    'contact:vk': 'https://vk.com/barspb_official'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3129739, 59.9640885]},
#   'properties': {'atm': 'yes',
#    'ref': '9055/0499',
#    'name': 'Сбербанк',
#    'phone': '+7-812-3462669',
#    'branch': 'Северо-Западный банк',
#    'amenity': 'bank',
#    'website': 'http://www.sberbank.ru/',
#    'operator': 'Сбербанк России',
#    'opening_hours': 'Mo-Fr 10:00-20:00; Sa 11:00-19:00; Su Off'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3204196, 59.9545201]},
#   'properties': {'name': 'Больше Кофе!',
#    'source': 'https://vk.com/morecoffee',
#    'amenity': 'cafe',
#    'cuisine': 'coffee_shop',
#    'name:en': 'More Coffee',
#    'smoking': 'no',
#    'addr:city': 'Санкт-Петербург',
#    'addr:place': 'Александровский парк',
#    'opening_hours': 'Mo-Th 10:00-22:00; Fr 10:00-23:00; Sa,Su 11:00-23:00',
#    'diet:vegetarian': 'yes',
#    'internet_access': 'wlan',
#    'outdoor_seating': 'yes',
#    'addr:housenumber': '3Г'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3222986, 59.9532626]},
#   'properties': {'name': 'Петербургский городской банк', 'amenity': 'atm'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4581999, 59.9155203]},
#   'properties': {'name': 'Радуга', 'amenity': 'pharmacy'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2880519, 59.9248608]},
#   'properties': {'name': 'У театра',
#    'amenity': 'pharmacy',
#    'contact:vk': 'https://vk.com/aptekayteatra',
#    'opening_hours': '24/7'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2891318, 59.9247749]},
#   'properties': {'name': 'Маска', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2870131, 59.9246274]},
#   'properties': {'amenity': 'atm',
#    'operator': 'ПАО Сбербанк',
#    'contact:website': 'https://www.sberbank.ru'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2887825, 59.9246956]},
#   'properties': {'name': 'Детский сад №60', 'amenity': 'kindergarten'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.288351, 59.9245978]},
#   'properties': {'name': 'Витал',
#    'amenity': 'pharmacy',
#    'operator': 'ЗАО "Аптека-Витал"',
#    'opening_hours': '09:00-22:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3758399, 59.9129149]},
#   'properties': {'name': 'Фаэтон', 'amenity': 'fuel'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4362654, 59.9328738]},
#   'properties': {'amenity': 'parking'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2960086, 59.9554791]},
#   'properties': {'name': 'Irish', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2951246, 59.955597]},
#   'properties': {'atm': 'yes',
#    'ref': '9055/0790',
#    'name': 'Сбербанк',
#    'phone': '+7-812-3252853',
#    'branch': 'Северо-Западный банк',
#    'amenity': 'bank',
#    'website': 'http://www.sberbank.ru/',
#    'operator': 'Сбербанк России',
#    'opening_hours': 'Mo-Fr 09:30-19:30; Sa 09:30-18:30'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3056479, 59.9620039]},
#   'properties': {'name': 'Теремок',
#    'source': 'survey',
#    'amenity': 'cafe',
#    'cuisine': 'regional',
#    'smoking': 'no',
#    'website': 'http://www.teremok.ru/places.phtml?place=203',
#    'payment:cash': 'yes',
#    'payment:visa': 'yes',
#    'opening_hours': 'Mo-Fr 09:00-22:00;Sa-Su 10:00-22:00',
#    'internet_access': 'wlan',
#    'payment:mastercard': 'yes'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3026106, 59.9575723]},
#   'properties': {'name': 'Библиотека имени В.И. Ленина',
#    'phone': '+7812232-40-60',
#    'amenity': 'library'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3085541, 59.9672811]},
#   'properties': {'amenity': 'atm',
#    'website': 'https://raiffeisen.ru/',
#    'operator': 'Райффайзен'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3119735, 59.9660911]},
#   'properties': {'name': 'БинБанк',
#    'amenity': 'atm',
#    'opening_hours': '24/7'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4186907, 59.8944727]},
#   'properties': {'name': 'Армида',
#    'phone': '+7(812)4120133',
#    'source': 'survey',
#    'amenity': 'driving_school',
#    'entrance': 'yes',
#    'operator': 'ООО "Автошкола Армида"',
#    'license_classes': 'B'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3024991, 59.9631017]},
#   'properties': {'name': 'Зелёный король',
#    'source': 'survey',
#    'amenity': 'pub'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2982222, 59.965611]},
#   'properties': {'name': 'Родник здоровья',
#    'amenity': 'pharmacy',
#    'opening_hours': 'Mo-Su 09:00-21:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2975931, 59.9652139]},
#   'properties': {'amenity': 'cafe', 'cuisine': 'local'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3147541, 59.9609368]},
#   'properties': {'name': 'Паутина', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3158104, 59.9611733]},
#   'properties': {'name': 'Coffee Noa',
#    'amenity': 'cafe',
#    'cuisine': 'coffee_shop',
#    'opening_hours': 'Mo-Th 08:00-23:00; Fr-Su 09:00-00:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3153883, 59.9614075]},
#   'properties': {'name': 'Остров',
#    'phone': '+7 812 2324143',
#    'amenity': 'restaurant',
#    'website': 'http://www.argus-beer.ru/ostrov'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.309297, 59.9675752]},
#   'properties': {'name': 'Марка', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3110293, 59.966808]},
#   'properties': {'name': 'Макдоналдс',
#    'phone': '+7 812 3460494',
#    'amenity': 'fast_food',
#    'cuisine': 'burger',
#    'name:de': "McDonald's",
#    'name:en': "McDonald's",
#    'name:ru': 'Макдоналдс',
#    'smoking': 'no',
#    'toilets': 'yes',
#    'website': 'http://www.mcdonalds.ru/',
#    'alt_name': 'Макдональдс',
#    'int_name': "McDonald's",
#    'operator': 'Макдоналдс',
#    'takeaway': 'yes',
#    'breakfast': '07:00-10:00',
#    'operator:en': "McDonald's",
#    'operator:ru': 'Макдоналдс',
#    'payment:cash': 'yes',
#    'payment:visa': 'yes',
#    'drive_through': 'no',
#    'opening_hours': '07:00-23:30',
#    'internet_access': 'wlan',
#    'outdoor_seating': 'yes',
#    'payment:maestro': 'yes',
#    'opening_hours:cafe': '07:00-23:00',
#    'payment:mastercard': 'yes'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3114102, 59.966663]},
#   'properties': {'name': 'KFC',
#    'brand': 'KFC',
#    'phone': '+7 812 2404835',
#    'amenity': 'fast_food',
#    'cuisine': 'chicken',
#    'name:de': 'KFC',
#    'name:en': 'KFC',
#    'smoking': 'no',
#    'website': 'http://www.kfc.ru/',
#    'alt_name': 'Kentucky Fried Chicken',
#    'int_name': 'KFC',
#    'old_name': 'Ростик’с-KFC / Ростикс',
#    'takeaway': 'yes',
#    'breakfast': 'yes',
#    'payment:cash': 'yes',
#    'payment:visa': 'yes',
#    'drive_through': 'no',
#    'opening_hours': '06:00-03:00',
#    'internet_access': 'wlan',
#    'outdoor_seating': 'no',
#    'payment:maestro': 'yes',
#    'payment:mastercard': 'yes'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.315539, 59.9560795]},
#   'properties': {'name': 'ParkKing', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.307789, 59.9633547]},
#   'properties': {'name': 'Две палочки',
#    'amenity': 'restaurant',
#    'cuisine': 'japanese;sushi',
#    'website': 'http://dvepalochki.ru/',
#    'alt_name': '2 палочки',
#    'contact:vk': 'https://vk.com/dvepalochki',
#    'opening_hours': 'Mo-Su 08:00-06:00',
#    'internet_access': 'wlan',
#    'payment:debit_cards': 'yes',
#    'payment:credit_cards': 'yes'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3092592, 59.9601434]},
#   'properties': {'amenity': 'pub'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2326179, 59.9480555]},
#   'properties': {'name': 'Две палочки',
#    'phone': '+7 800 2202020',
#    'amenity': 'restaurant',
#    'cuisine': 'japanese;sushi',
#    'website': 'http://dvepalochki.ru/',
#    'alt_name': '2 палочки',
#    'delivery': 'yes',
#    'entrance': 'yes',
#    'operator': 'Мост',
#    'takeaway': 'yes',
#    'contact:vk': 'https://vk.com/dvepalochki',
#    'payment:visa': 'yes',
#    'opening_hours': 'Mo-Su 09:00-06:00',
#    'internet_access': 'wlan',
#    'payment:mastercard': 'yes',
#    'payment:visa_debit': 'yes',
#    'payment:visa_electron': 'yes'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3025373, 59.9705883]},
#   'properties': {'access': 'private',
#    'amenity': 'parking',
#    'parking': 'surface'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3088402, 59.9577855]},
#   'properties': {'name': 'Сбербанк',
#    'branch': 'Северо-Западный банк',
#    'amenity': 'atm',
#    'website': 'http://www.sberbank.ru/',
#    'operator': 'Сбербанк России',
#    'opening_hours': '24/7'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3083526, 59.9577074]},
#   'properties': {'name': 'Первая помощь',
#    'phone': '+7 812 2339971',
#    'amenity': 'pharmacy',
#    'website': 'http://www.aptekapp.ru/',
#    'opening_hours': '08:00-22:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3080517, 59.957651]},
#   'properties': {'name': 'Тбилисо',
#    'phone': '+7 812 2329391',
#    'amenity': 'restaurant',
#    'cuisine': 'georgian',
#    'website': 'http://triton-restoran.ru/restaurants/tbiliso/about',
#    'operator': 'Ресторанная группа «Тритон»',
#    'opening_hours': '12:00-00:00',
#    'internet_access': 'wlan'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2958136, 59.9640473]},
#   'properties': {'ref': '36',
#    'name': 'Петербургские аптеки',
#    'phone': '+7 812 2306252',
#    'amenity': 'pharmacy',
#    'website': 'http://www.papteki.ru/',
#    'opening_hours': 'Mo-Fr 10:00-19:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2981903, 59.9607314]},
#   'properties': {'name': 'Вега', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3014564, 59.9594554]},
#   'properties': {'ref': 'Петроградский',
#    'name': 'ОТП Банк',
#    'phone': '+7 812 4934868; +7 812 4934866; +7 812 4933066',
#    'amenity': 'bank',
#    'website': 'https://www.otpbank.ru/',
#    'operator': 'ОТП Банк',
#    'opening_hours': 'Mo-Fr 09:30-20:30, Sa 09:30-16:45'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.303103, 59.9594377]},
#   'properties': {'name': 'Molly Sullivan',
#    'phone': '+78127777966',
#    'amenity': 'pub',
#    'website': 'http://molly.su/',
#    'alt_name': 'Молли Салливан',
#    'operator': "Mollie's Group",
#    'description': 'хотя написано restaurant & bar, на табличке — & pub',
#    'opening_hours': 'Mo-Th 12:00-02:00; Fr-Sa 12:00-03:00; Su 12:00-01:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3130539, 59.9570889]},
#   'properties': {'name': 'Дамаск', 'amenity': 'restaurant'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3228681, 59.9335447]},
#   'properties': {'ref': '1',
#    'amenity': 'post_box',
#    'operator': 'Почта России',
#    'design:year': '2010',
#    'drive_through': 'no',
#    'post_box:type': 'wall',
#    'post_box:design': 'ЯПНМ-II-С',
#    'collection_times': 'Mo-Fr 05:50,17:00; Sa 08:05; Su 17:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3285269, 59.9349179]},
#   'properties': {'ref': '62',
#    'amenity': 'post_box',
#    'operator': 'Почта России',
#    'design:year': '2010',
#    'drive_through': 'no',
#    'post_box:type': 'wall',
#    'post_box:design': 'ЯПНМ-II-С',
#    'collection_times': 'Mo-Fr 04:35,12:55; Sa 08:35; Su 12:55'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3417932, 59.9363086]},
#   'properties': {'name': 'Дом кино',
#    'amenity': 'cinema',
#    'website': 'http://domkinospb.com/'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3066815, 59.9528379]},
#   'properties': {'amenity': 'toilets'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3052363, 59.930489]},
#   'properties': {'name': 'Американская Медицинская Клиника',
#    'amenity': 'doctors',
#    'name:en': 'American Medical Clinic',
#    'name:ru': 'Американская Медицинская Клиника',
#    'website': 'http://amclinic.ru/',
#    'operator': 'ООО «Американская Медицинская Клиника»',
#    'contact:vk': 'https://vk.com/amclinic_spb',
#    'opening_hours': '09:00-20:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.2972882, 59.9523046]},
#   'properties': {'name': 'Наш Питер',
#    'amenity': 'restaurant',
#    'cuisine': 'regional'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3754386, 59.9136572]},
#   'properties': {'name': 'Dinner Hall', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3769343, 59.9140452]},
#   'properties': {'name': 'Амилен', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4911013, 59.9284983]},
#   'properties': {'access': 'private', 'amenity': 'parking'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.320967, 59.8761352]},
#   'properties': {'name': 'Уголёк', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3631958, 59.9385941]},
#   'properties': {'name': 'The Templet Bar',
#    'phone': '+7-812-5791855',
#    'amenity': 'pub',
#    'website': 'http://templetbar.ru/templet-centr/',
#    'operator': 'ООО "Вуд"',
#    'contact:vk': 'https://vk.com/templetbar',
#    'opening_hours': '12:00-02:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4397157, 59.974071]},
#   'properties': {'amenity': 'fuel'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3238878, 59.9273912]},
#   'properties': {'food': 'yes',
#    'name': 'Bier König',
#    'amenity': 'pub',
#    'website': 'http://www.bier-konig.ru/locations/bier-k%C3%B6nig-%D0%BD%D0%B0-%D0%B3%D0%BE%D1%80%D0%BE%D1%85%D0%BE%D0%B2%D0%BE%D0%B9',
#    'operator': 'ООО "ТДЛ"',
#    'contact:vk': 'https://vk.com/bierkoniig',
#    'opening_hours': 'Su-Th 12:00-01:00, Fr-Sa 12:00-02:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4755116, 59.9397604]},
#   'properties': {'name': 'Васаби', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4792091, 59.9438655]},
#   'properties': {'name': 'Пури', 'amenity': 'restaurant'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4592033, 59.9219213]},
#   'properties': {'name': 'Авангард', 'amenity': 'bank'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4578285, 59.9223035]},
#   'properties': {'atm': 'yes',
#    'name': 'Сбербанк',
#    'amenity': 'bank',
#    'website': 'http://www.sberbank.ru/',
#    'operator': 'Сбербанк России',
#    'addr:city': 'Санкт-Петербург',
#    'addr:street': 'проспект Пятилеток',
#    'addr:postcode': '193318',
#    'addr:housenumber': '10 к1'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4755822, 59.9400724]},
#   'properties': {'atm': 'yes',
#    'ref': '8074/0755',
#    'name': 'Сбербанк',
#    'amenity': 'bank',
#    'website': 'http://sberbank.ru/'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4775021, 59.9388014]},
#   'properties': {'name': 'Первая помощь',
#    'amenity': 'pharmacy',
#    'dispensing': 'no'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4905096, 59.9382466]},
#   'properties': {'name': 'Домино', 'amenity': 'nightclub'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4785081, 59.9424853]},
#   'properties': {'name': 'Детская библиотека', 'amenity': 'library'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4857888, 59.9455088]},
#   'properties': {'name': 'Радуга',
#    'amenity': 'pharmacy',
#    'dispensing': 'no',
#    'opening_hours': 'Mo-Su 00:05-03:00,03:45-23:45'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4741153, 59.9477852]},
#   'properties': {'atm': 'yes',
#    'name': 'Сбербанк',
#    'amenity': 'bank',
#    'website': 'http://www.sberbank.ru/',
#    'operator': 'Сбербанк России'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4925689, 59.8963785]},
#   'properties': {'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4925451, 59.8962563]},
#   'properties': {'name': 'Автомойка', 'amenity': 'car_wash'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4754165, 59.9669899]},
#   'properties': {'name': 'Барселона', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4747441, 59.9382196]},
#   'properties': {'name': 'Шахеризада', 'amenity': 'cafe'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4748425, 59.9386972]},
#   'properties': {'name': 'Мировые судьи', 'amenity': 'courthouse'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4835288, 59.9083944]},
#   'properties': {'name': 'Каро фильм',
#    'amenity': 'cinema',
#    'website': 'http://www.karofilm.ru/',
#    'operator': 'КАРО Фильм'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4464556, 59.9118261]},
#   'properties': {'name': 'Формула Кино',
#    'amenity': 'cinema',
#    'website': 'http://www.formulakino.ru'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4451811, 59.9112941]},
#   'properties': {'ref': '550786',
#    'name': 'Сбербанк',
#    'phone': '+7 800 5555550',
#    'source': 'survey',
#    'amenity': 'atm',
#    'cash_in': 'no',
#    'website': 'http://sberbank.ru/',
#    'operator': 'Сбербанк России',
#    'addr:city': 'Санкт-Петербург',
#    'check_date': '2012-12-13',
#    'addr:street': 'улица Коллонтай',
#    'description': 'перед кассовой зоной магазина Леруа Мерлен',
#    'opening_hours': '08:30-22:00',
#    'addr:housenumber': '3'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.327654, 59.9330229]},
#   'properties': {'name': 'Fidel',
#    'amenity': 'bar',
#    'name:ru': 'Фидель',
#    'contact:vk': 'https://vk.com/club6021859',
#    'start_date': '2006',
#    'opening_hours': 'Mo-Su 20:00-06:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.471654, 59.917244]},
#   'properties': {'name': 'Государственная аптека',
#    'amenity': 'pharmacy',
#    'dispensing': 'yes',
#    'opening_hours': 'Mo-Su 08:00-22:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4724255, 59.9189957]},
#   'properties': {'name': 'Евразия',
#    'amenity': 'restaurant',
#    'cuisine': 'japanese'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4837624, 59.9084121]},
#   'properties': {'name': 'Гермес', 'amenity': 'biergarten'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4574083, 59.8772638]},
#   'properties': {'name': 'Мастерская',
#    'amenity': 'theatre',
#    'wikidata': 'Q4407736',
#    'wikipedia': 'ru:Санкт-Петербургский театр «Мастерская»'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.468618, 59.9119574]},
#   'properties': {'name': 'Камелот', 'amenity': 'pub'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.4720955, 59.9169252]},
#   'properties': {'name': 'Две палочки',
#    'amenity': 'restaurant',
#    'cuisine': 'japanese;sushi',
#    'website': 'http://dvepalochki.ru/',
#    'alt_name': '2 палочки',
#    'contact:vk': 'https://vk.com/dvepalochki',
#    'opening_hours': 'Mo-Su 11:00-06:00',
#    'internet_access': 'wlan',
#    'payment:debit_cards': 'yes',
#    'payment:credit_cards': 'yes'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3539856, 59.9590493]},
#   'properties': {'atm': 'yes',
#    'name': 'Альфа-Банк',
#    'amenity': 'bank',
#    'website': 'http://alfabank.ru/',
#    'operator': 'Альфа-Банк',
#    'opening_hours': 'Mo-Fr 09:00-20:00; Sa 10:00-19:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3236834, 59.9336636]},
#   'properties': {'atm': 'yes',
#    'name': 'Альфа Private',
#    'amenity': 'bank',
#    'website': 'https://alfabank.ru/office/peterburg/246/',
#    'operator': 'Альфа-Банк',
#    'contact:vk': 'https://vk.com/alfabank',
#    'opening_hours': 'Mo-Sa 09:30-21:00'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [30.3570735, 59.9254899]},
#   'properties': {'atm': 'yes',
#    'name': 'Альфа-Банк',
#    'note': 'здесь же ещё один офис с другим режимом работы: https://alfabank.ru/office/peterburg/ligovsky/',
#    'amenity': 'bank',
#    'website': 'https://alfabank.ru/office/peterburg/neva/',
#    'operator': 'Альфа-Банк',
#    'contact:vk': 'https://vk.com/alfabank',
#    'opening_hours': 'Mo-Fr 09:00-20:00; Sa 10:00-19:00; Su 12:00-17:00'}}]

# %%
len(entries['subway_station'])
# Out:
# 45

# %%
'''
without_amenity = [f for f in with_other_tags if f not in with_amenity]

def subset(tag, value=None, data=with_other_tags): 
    res = [f for f in data if tag in f['properties']['other_tags'].keys()]
    if not value is None:
        res = [f for f in res if f['properties']['other_tags'][tag] == value]
    return res

shit_pairs = [['merkator_shift:bing'], 
              ['crossing'], 
              ['traffic_signals', 'signal'],            
              ['natural', 'tree'], 
              ['entrance'], 
              ['bicycle'], 
              ['power'], 
              ['foot'], 
              ['building:levels'], 
              ['name:en'],
              ['noexit'],
              ['phone'],
              ['bench'],
              ['traffic_calming'],
              ['shop', 'kiosk'], 
              ['shop', 'laundry'], 
              ['shop', 'hairdresser'], 
              ['addr:city'], 
              ['access'], 
              ['vehicle'], 
              ['building'], 
              ['direction']]

shit = list(itertools.chain(*[subset(*s) for s in shit_pairs]))
features_without_shit = [f for f in with_other_tags if f not in shit]
'''
